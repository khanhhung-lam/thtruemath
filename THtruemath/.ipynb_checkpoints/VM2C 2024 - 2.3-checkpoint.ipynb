# %%
from gurobipy import *
import pandas as pd
from datetime import datetime, timedelta

# lấy dữ liệu

dataTC = pd.read_csv(r"D:\vm2c 2024\Data2_2_1\TransCost.csv", header=None)
trans_cost = dataTC.values.tolist() #TransCost[i][j] là tiền vận chuyển từ nhà máy i đến cửa hàng j

dataDM = pd.read_csv(r"D:\vm2c 2024\Data2_3\demandAdd.csv")
dataDM = pd.DataFrame(dataDM, columns=["STT", "hoanh", "tung", "demand"])
demand = dataDM["demand"].values.tolist() #mảng 1 chiều biểu thị nhu cầu của 200 cửa hàng
total_demand = sum(i for i in demand)

dataFAC = pd.read_csv(r"D:\vm2c 2024\Data2_2_1\facility.csv")
dataFAC = pd.DataFrame(dataFAC, columns=["STT", "hoanh", "tung", "CongSuat", "ChiPhi"])
facility = dataFAC[["CongSuat", "ChiPhi"]].values.tolist() #facility[i][j] biểu thị công suất (j = 0) hoặc chi phí (j = 1) của nhà máy thứ i
total_demand
# Out:
# 6991

# %%
num_facility = 10
num_shop = 200
model = Model()
b = model.addVars(num_facility, vtype = GRB.BINARY, name = 'b')
total_trans_item = model.addVars(num_facility, num_shop, vtype = GRB.INTEGER, name = 'total_trans_item', lb = 0, ub = total_demand)
total_trans_value = model.addVars(num_facility, num_shop, vtype = GRB.CONTINUOUS, name = 'total_trans_value', lb = 0, ub = GRB.INFINITY)
# ràng buộc shop thứ j nhập về đủ hàng từ tất cả nhà máy so với nhu cầu
for j in range(num_shop):
    model.addConstr(quicksum(total_trans_item[i,j] for i in range(num_facility)) == demand[j])
    #ràng buộc để xác định tổng tiền vận chuyển
    for i in range(num_facility):
        model.addConstr(total_trans_value[i,j] == total_trans_item[i,j]*trans_cost[i][j])
# ràng buộc tổng số hàng vận chuyển cho các cửa hàng của từng nhà máy phải nhỏ hơn hoặc bằng sản lượng của nhà máy đó
for i in range(num_facility):
    model.addConstr(quicksum(total_trans_item[i,j] for j in range(num_shop)) <= facility[i][0])
    for j in range(num_shop):
        model.addConstr(total_trans_item[i, j] <= total_demand * b[i])
# ràng buộc tổng sản lượng của tất cả nhà máy phải lớn hơn hoặc bằng tổng nhu cầu
model.addConstr(total_demand <= quicksum(facility[i][0]*b[i] for i in range(num_facility)))
obj_fn = quicksum(total_trans_value[i,j] for i in range(num_facility) for j in range(num_shop)) + quicksum(facility[i][1]*b[i] for i in range(num_facility))
model.setObjective(obj_fn, GRB.MINIMIZE)
model.optimize()
if model.status == GRB.OPTIMAL:
    for i in range(num_facility):
        print(b[i].x, end = ' ')
    for i in range(num_facility):
        if b[i].x == 1:
            for j in range(num_shop):
                if total_trans_item[i,j].x > 0:
                    print(f'fac {i+1} transported {total_trans_item[i,j].x} items to shop {j+1}')
    for i in range(num_facility):
        print(quicksum(total_trans_item[i,j].x for j in range(num_shop)))
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 4211 rows, 4010 columns and 12010 nonzeros
# Model fingerprint: 0xae7d0e69
# Variable types: 2000 continuous, 2010 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 7e+03]
#   Objective range  [1e+00, 7e+02]
#   Bounds range     [1e+00, 7e+03]
#   RHS range        [1e+01, 7e+03]
# Found heuristic solution: objective 19155.830000
# Presolve removed 2000 rows and 2000 columns
# Presolve time: 0.01s
# Presolved: 2211 rows, 2010 columns, 8010 nonzeros
# Variable types: 0 continuous, 2010 integer (10 binary)
# Found heuristic solution: objective 19128.950000
#
# Root relaxation: objective 1.599062e+04, 421 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 15990.6185    0  129 19128.9500 15990.6185  16.4%     -    0s
# H    0     0                    16593.480000 15990.6185  3.63%     -    0s
# H    0     0                    16590.700000 15990.6185  3.62%     -    0s
# H    0     0                    16547.470000 15990.6185  3.37%     -    0s
# H    0     0                    16535.210000 15990.6185  3.29%     -    0s
#      0     0 16069.0398    0  256 16535.2100 16069.0398  2.82%     -    0s
#      0     0 16080.0145    0  225 16535.2100 16080.0145  2.75%     -    0s
#      0     0 16122.0128    0  215 16535.2100 16122.0128  2.50%     -    0s
# H    0     0                    16142.560000 16122.0128  0.13%     -    0s
#
# Cutting planes:
#   Implied bound: 3
#   MIR: 7
#
# Explored 1 nodes (707 simplex iterations) in 0.14 seconds (0.13 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 8: 16142.6 16142.6 16535.2 ... 19155.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.614256000000e+04, best bound 1.614256000000e+04, gap 0.0000%
# 0.0 1.0 1.0 1.0 0.0 1.0 0.0 1.0 1.0 1.0 fac 2 transported 43.0 items to shop 80
# fac 2 transported 44.0 items to shop 98
# fac 2 transported 46.0 items to shop 106
# fac 2 transported 39.0 items to shop 109
# fac 2 transported 35.0 items to shop 112
# fac 2 transported 50.0 items to shop 113
# fac 2 transported 19.0 items to shop 114
# fac 2 transported 52.0 items to shop 120
# fac 2 transported 14.0 items to shop 121
# fac 2 transported 29.0 items to shop 125
# fac 2 transported 28.0 items to shop 126
# fac 2 transported 21.0 items to shop 127
# fac 2 transported 25.0 items to shop 128
# fac 2 transported 36.0 items to shop 130
# fac 2 transported 41.0 items to shop 131
# fac 2 transported 23.0 items to shop 140
# fac 2 transported 14.0 items to shop 143
# fac 2 transported 26.0 items to shop 144
# fac 2 transported 10.0 items to shop 145
# fac 2 transported 29.0 items to shop 146
# fac 2 transported 26.0 items to shop 160
# fac 2 transported 31.0 items to shop 164
# fac 2 transported 41.0 items to shop 166
# fac 2 transported 45.0 items to shop 169
# fac 2 transported 41.0 items to shop 171
# fac 2 transported 48.0 items to shop 173
# fac 2 transported 34.0 items to shop 180
# fac 2 transported 22.0 items to shop 187
# fac 2 transported 30.0 items to shop 196
# fac 2 transported 19.0 items to shop 198
# fac 2 transported 30.0 items to shop 199
# fac 3 transported 21.0 items to shop 11
# fac 3 transported 22.0 items to shop 13
# fac 3 transported 28.0 items to shop 19
# fac 3 transported 43.0 items to shop 30
# fac 3 transported 16.0 items to shop 34
# fac 3 transported 37.0 items to shop 40
# fac 3 transported 25.0 items to shop 41
# fac 3 transported 20.0 items to shop 44
# fac 3 transported 35.0 items to shop 45
# fac 3 transported 19.0 items to shop 55
# fac 3 transported 29.0 items to shop 57
# fac 3 transported 23.0 items to shop 59
# fac 3 transported 26.0 items to shop 63
# fac 3 transported 34.0 items to shop 64
# fac 3 transported 38.0 items to shop 66
# fac 3 transported 41.0 items to shop 70
# fac 3 transported 44.0 items to shop 82
# fac 3 transported 10.0 items to shop 85
# fac 3 transported 38.0 items to shop 88
# fac 3 transported 48.0 items to shop 95
# fac 3 transported 23.0 items to shop 97
# fac 3 transported 44.0 items to shop 100
# fac 3 transported 41.0 items to shop 108
# fac 3 transported 41.0 items to shop 119
# fac 3 transported 34.0 items to shop 124
# fac 3 transported 25.0 items to shop 139
# fac 3 transported 41.0 items to shop 153
# fac 3 transported 36.0 items to shop 158
# fac 3 transported 44.0 items to shop 167
# fac 3 transported 23.0 items to shop 188
# fac 3 transported 51.0 items to shop 195
# fac 4 transported 40.0 items to shop 1
# fac 4 transported 41.0 items to shop 5
# fac 4 transported 32.0 items to shop 6
# fac 4 transported 24.0 items to shop 7
# fac 4 transported 56.0 items to shop 8
# fac 4 transported 31.0 items to shop 9
# fac 4 transported 56.0 items to shop 12
# fac 4 transported 18.0 items to shop 15
# fac 4 transported 55.0 items to shop 20
# fac 4 transported 29.0 items to shop 22
# fac 4 transported 28.0 items to shop 26
# fac 4 transported 43.0 items to shop 32
# fac 4 transported 51.0 items to shop 37
# fac 4 transported 26.0 items to shop 43
# fac 4 transported 17.0 items to shop 46
# fac 4 transported 47.0 items to shop 47
# fac 4 transported 38.0 items to shop 51
# fac 4 transported 36.0 items to shop 54
# fac 4 transported 31.0 items to shop 58
# fac 4 transported 34.0 items to shop 74
# fac 4 transported 36.0 items to shop 76
# fac 4 transported 35.0 items to shop 78
# fac 4 transported 54.0 items to shop 79
# fac 4 transported 35.0 items to shop 85
# fac 4 transported 26.0 items to shop 86
# fac 4 transported 2.0 items to shop 87
# fac 4 transported 55.0 items to shop 93
# fac 4 transported 24.0 items to shop 94
# fac 6 transported 38.0 items to shop 2
# fac 6 transported 44.0 items to shop 3
# fac 6 transported 47.0 items to shop 4
# fac 6 transported 25.0 items to shop 10
# fac 6 transported 27.0 items to shop 14
# fac 6 transported 27.0 items to shop 16
# fac 6 transported 30.0 items to shop 23
# fac 6 transported 51.0 items to shop 25
# fac 6 transported 36.0 items to shop 27
# fac 6 transported 17.0 items to shop 28
# fac 6 transported 18.0 items to shop 31
# fac 6 transported 43.0 items to shop 33
# fac 6 transported 43.0 items to shop 38
# fac 6 transported 55.0 items to shop 48
# fac 6 transported 27.0 items to shop 50
# fac 6 transported 17.0 items to shop 56
# fac 6 transported 40.0 items to shop 61
# fac 6 transported 41.0 items to shop 62
# fac 6 transported 52.0 items to shop 65
# fac 6 transported 24.0 items to shop 72
# fac 6 transported 24.0 items to shop 73
# fac 6 transported 22.0 items to shop 81
# fac 6 transported 40.0 items to shop 83
# fac 6 transported 45.0 items to shop 84
# fac 6 transported 23.0 items to shop 87
# fac 6 transported 43.0 items to shop 90
# fac 6 transported 50.0 items to shop 96
# fac 6 transported 51.0 items to shop 99
# fac 8 transported 48.0 items to shop 18
# fac 8 transported 44.0 items to shop 24
# fac 8 transported 7.0 items to shop 28
# fac 8 transported 43.0 items to shop 29
# fac 8 transported 46.0 items to shop 36
# fac 8 transported 20.0 items to shop 39
# fac 8 transported 42.0 items to shop 42
# fac 8 transported 46.0 items to shop 52
# fac 8 transported 40.0 items to shop 60
# fac 8 transported 44.0 items to shop 67
# fac 8 transported 34.0 items to shop 68
# fac 8 transported 47.0 items to shop 69
# fac 8 transported 47.0 items to shop 71
# fac 8 transported 32.0 items to shop 75
# fac 8 transported 52.0 items to shop 77
# fac 8 transported 16.0 items to shop 89
# fac 8 transported 37.0 items to shop 91
# fac 8 transported 58.0 items to shop 92
# fac 8 transported 24.0 items to shop 107
# fac 8 transported 42.0 items to shop 148
# fac 8 transported 52.0 items to shop 149
# fac 8 transported 26.0 items to shop 157
# fac 8 transported 51.0 items to shop 162
# fac 8 transported 47.0 items to shop 181
# fac 8 transported 30.0 items to shop 186
# fac 8 transported 25.0 items to shop 197
# fac 9 transported 34.0 items to shop 17
# fac 9 transported 19.0 items to shop 21
# fac 9 transported 32.0 items to shop 35
# fac 9 transported 50.0 items to shop 49
# fac 9 transported 33.0 items to shop 53
# fac 9 transported 3.0 items to shop 57
# fac 9 transported 39.0 items to shop 103
# fac 9 transported 20.0 items to shop 104
# fac 9 transported 35.0 items to shop 111
# fac 9 transported 34.0 items to shop 116
# fac 9 transported 20.0 items to shop 117
# fac 9 transported 36.0 items to shop 122
# fac 9 transported 51.0 items to shop 133
# fac 9 transported 51.0 items to shop 134
# fac 9 transported 32.0 items to shop 135
# fac 9 transported 49.0 items to shop 136
# fac 9 transported 45.0 items to shop 137
# fac 9 transported 34.0 items to shop 142
# fac 9 transported 40.0 items to shop 147
# fac 9 transported 23.0 items to shop 154
# fac 9 transported 19.0 items to shop 155
# fac 9 transported 41.0 items to shop 159
# fac 9 transported 43.0 items to shop 163
# fac 9 transported 30.0 items to shop 177
# fac 9 transported 26.0 items to shop 178
# fac 9 transported 27.0 items to shop 179
# fac 9 transported 27.0 items to shop 185
# fac 9 transported 11.0 items to shop 190
# fac 9 transported 30.0 items to shop 191
# fac 9 transported 26.0 items to shop 193
# fac 9 transported 14.0 items to shop 194
# fac 9 transported 26.0 items to shop 200
# fac 10 transported 24.0 items to shop 101
# fac 10 transported 35.0 items to shop 102
# fac 10 transported 52.0 items to shop 105
# fac 10 transported 29.0 items to shop 110
# fac 10 transported 39.0 items to shop 115
# fac 10 transported 24.0 items to shop 118
# fac 10 transported 52.0 items to shop 123
# fac 10 transported 35.0 items to shop 129
# fac 10 transported 31.0 items to shop 132
# fac 10 transported 27.0 items to shop 138
# fac 10 transported 25.0 items to shop 141
# fac 10 transported 23.0 items to shop 145
# fac 10 transported 28.0 items to shop 150
# fac 10 transported 31.0 items to shop 151
# fac 10 transported 36.0 items to shop 152
# fac 10 transported 22.0 items to shop 156
# fac 10 transported 51.0 items to shop 161
# fac 10 transported 21.0 items to shop 165
# fac 10 transported 18.0 items to shop 168
# fac 10 transported 48.0 items to shop 170
# fac 10 transported 43.0 items to shop 172
# fac 10 transported 50.0 items to shop 174
# fac 10 transported 30.0 items to shop 175
# fac 10 transported 21.0 items to shop 176
# fac 10 transported 56.0 items to shop 182
# fac 10 transported 30.0 items to shop 183
# fac 10 transported 51.0 items to shop 184
# fac 10 transported 16.0 items to shop 189
# fac 10 transported 13.0 items to shop 190
# fac 10 transported 39.0 items to shop 192
# 0.0
# 991.0
# 1000.0
# 1000.0
# 0.0
# 1000.0
# 0.0
# 1000.0
# 1000.0
# 1000.0
